# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.speedtest.net/global-index'

response = requests.get(url)

if response.status_code == 200:
    print('Successfully fetched the webpage...')

    soup = BeautifulSoup(response.content, 'html.parser')

    mobile_element = soup.find(id='column-mobileMedian')
    broadband_element = soup.find(id='column-fixedMedian')

    countries_summary_mobile = mobile_element.find(class_='countriesSummary').find_all('a')
    cities_summary_mobile = mobile_element.find(class_='citiesSummary').find_all('a')

    countries_summary_broadband = broadband_element.find(class_='countriesSummary').find_all('a')
    cities_summary_broadband = broadband_element.find(class_='citiesSummary').find_all('a')
else:
    print('Failed to fetch the webpage. Status code:', response.status_code)
# Out:
# Successfully fetched the webpage...

# %%
def fetch_data(summary, soup_id, type):
    info = []

    failed_entries = []

    for link in summary:
        res = requests.get(f"https://www.speedtest.net{link.get('href')}")

        if res.status_code == 200:
          print('Successfully fetched the webpage for ->', link.text.strip(), f"https://www.speedtest.net{link.get('href')}")

          soup = BeautifulSoup(res.content, 'html.parser')

          data = soup.find(id=soup_id)

          rank = data.find(class_='headings').find(class_='rank').find(class_='number').text.strip()
          rank_change = data.find(class_='headings').find(class_='rank').find(class_='rank-change').text.strip()

          download = data.find(class_='headings').find(class_='download').find(class_='number').text.strip()

          upload = data.find(class_='headings').find(class_='upload').find(class_='number').text.strip()

          latency = data.find(class_='headings').find(class_='latency').find(class_='number').text.strip()

          info.append({
              type: link.text.strip(),
              "position": rank, # rank named column not allowed
              "rank_change": rank_change,
              "download": download,
              "upload": upload,
              "latency": latency
          })
        else:
          failed_entries.append(link)

          print('Failed to fetch the webpage for ->', link.text.strip())

    return info, failed_entries

# %%
countries_mobile_data, failed_country_mobile = fetch_data(countries_summary_mobile, 'column-mobileMedian', 'country')
cities_mobile_data, failed_city_mobile = fetch_data(cities_summary_mobile, 'column-mobileCitiesMedian', 'city')

countries_broadband_data, failed_country_broadband = fetch_data(countries_summary_broadband, 'column-fixedMedian', 'country')
cities_broadband_data, failed_city_broadband = fetch_data(cities_summary_broadband, 'column-fixedCitiesMedian', 'city')
# Out:
# Successfully fetched the webpage for -> Qatar https://www.speedtest.net/global-index/qatar#mobile
# Successfully fetched the webpage for -> United Arab Emirates https://www.speedtest.net/global-index/united-arab-emirates#mobile
# Successfully fetched the webpage for -> Kuwait https://www.speedtest.net/global-index/kuwait#mobile
# Successfully fetched the webpage for -> Iceland https://www.speedtest.net/global-index/iceland#mobile
# Successfully fetched the webpage for -> South Korea https://www.speedtest.net/global-index/south-korea#mobile
# Successfully fetched the webpage for -> Denmark https://www.speedtest.net/global-index/denmark#mobile
# Successfully fetched the webpage for -> China https://www.speedtest.net/global-index/china#mobile
# Successfully fetched the webpage for -> Netherlands https://www.speedtest.net/global-index/netherlands#mobile
# Successfully fetched the webpage for -> United States https://www.speedtest.net/global-index/united-states#mobile
# Successfully fetched the webpage for -> Macau (SAR) https://www.speedtest.net/global-index/macau-(sar)#mobile
# Successfully fetched the webpage for -> Saudi Arabia https://www.speedtest.net/global-index/saudi-arabia#mobile
# Successfully fetched the webpage for -> Bahrain https://www.speedtest.net/global-index/bahrain#mobile
# Successfully fetched the webpage for -> Norway https://www.speedtest.net/global-index/norway#mobile
# Successfully fetched the webpage for -> Lithuania https://www.speedtest.net/global-index/lithuania#mobile
# Successfully fetched the webpage for -> Bulgaria https://www.speedtest.net/global-index/bulgaria#mobile
# Successfully fetched the webpage for -> India https://www.speedtest.net/global-index/india#mobile
# Successfully fetched the webpage for -> Brunei https://www.speedtest.net/global-index/brunei#mobile
# Successfully fetched the webpage for -> Canada https://www.speedtest.net/global-index/canada#mobile
# Successfully fetched the webpage for -> Finland https://www.speedtest.net/global-index/finland#mobile
# Successfully fetched the webpage for -> Sweden https://www.speedtest.net/global-index/sweden#mobile
# Successfully fetched the webpage for -> Croatia https://www.speedtest.net/global-index/croatia#mobile
# Successfully fetched the webpage for -> France https://www.speedtest.net/global-index/france#mobile
# Successfully fetched the webpage for -> Singapore https://www.speedtest.net/global-index/singapore#mobile
# Successfully fetched the webpage for -> Luxembourg https://www.speedtest.net/global-index/luxembourg#mobile
# Successfully fetched the webpage for -> Estonia https://www.speedtest.net/global-index/estonia#mobile
# Successfully fetched the webpage for -> Switzerland https://www.speedtest.net/global-index/switzerland#mobile
# Successfully fetched the webpage for -> Malaysia https://www.speedtest.net/global-index/malaysia#mobile
# Successfully fetched the webpage for -> Latvia https://www.speedtest.net/global-index/latvia#mobile
# Successfully fetched the webpage for -> North Macedonia https://www.speedtest.net/global-index/north-macedonia#mobile
# Successfully fetched the webpage for -> Portugal https://www.speedtest.net/global-index/portugal#mobile
# Successfully fetched the webpage for -> Australia https://www.speedtest.net/global-index/australia#mobile
# Successfully fetched the webpage for -> Maldives https://www.speedtest.net/global-index/maldives#mobile
# Successfully fetched the webpage for -> Austria https://www.speedtest.net/global-index/austria#mobile
# Successfully fetched the webpage for -> Taiwan https://www.speedtest.net/global-index/taiwan#mobile
# Successfully fetched the webpage for -> Malta https://www.speedtest.net/global-index/malta#mobile
# Successfully fetched the webpage for -> Slovenia https://www.speedtest.net/global-index/slovenia#mobile
# Successfully fetched the webpage for -> Belgium https://www.speedtest.net/global-index/belgium#mobile
# Successfully fetched the webpage for -> Greece https://www.speedtest.net/global-index/greece#mobile
# Successfully fetched the webpage for -> Oman https://www.speedtest.net/global-index/oman#mobile
# Successfully fetched the webpage for -> Czechia https://www.speedtest.net/global-index/czechia#mobile
# Successfully fetched the webpage for -> Uruguay https://www.speedtest.net/global-index/uruguay#mobile
# Successfully fetched the webpage for -> New Zealand https://www.speedtest.net/global-index/new-zealand#mobile
# Successfully fetched the webpage for -> Hong Kong (SAR) https://www.speedtest.net/global-index/hong-kong-(sar)#mobile
# Successfully fetched the webpage for -> Romania https://www.speedtest.net/global-index/romania#mobile
# Successfully fetched the webpage for -> Cyprus https://www.speedtest.net/global-index/cyprus#mobile
# Successfully fetched the webpage for -> Montenegro https://www.speedtest.net/global-index/montenegro#mobile
# Successfully fetched the webpage for -> Poland https://www.speedtest.net/global-index/poland#mobile
# Successfully fetched the webpage for -> Germany https://www.speedtest.net/global-index/germany#mobile
# Successfully fetched the webpage for -> Mauritius https://www.speedtest.net/global-index/mauritius#mobile
# Successfully fetched the webpage for -> Brazil https://www.speedtest.net/global-index/brazil#mobile
# Successfully fetched the webpage for -> United Kingdom https://www.speedtest.net/global-index/united-kingdom#mobile
# Successfully fetched the webpage for -> Slovakia https://www.speedtest.net/global-index/slovakia#mobile
# Successfully fetched the webpage for -> Serbia https://www.speedtest.net/global-index/serbia#mobile
# Successfully fetched the webpage for -> Albania https://www.speedtest.net/global-index/albania#mobile
# Successfully fetched the webpage for -> Italy https://www.speedtest.net/global-index/italy#mobile
# Successfully fetched the webpage for -> Azerbaijan https://www.speedtest.net/global-index/azerbaijan#mobile
# Successfully fetched the webpage for -> South Africa https://www.speedtest.net/global-index/south-africa#mobile
# Successfully fetched the webpage for -> Hungary https://www.speedtest.net/global-index/hungary#mobile
# Successfully fetched the webpage for -> Vietnam https://www.speedtest.net/global-index/vietnam#mobile
# Successfully fetched the webpage for -> Japan https://www.speedtest.net/global-index/japan#mobile
# Successfully fetched the webpage for -> Spain https://www.speedtest.net/global-index/spain#mobile
# Successfully fetched the webpage for -> Togo https://www.speedtest.net/global-index/togo#mobile
# Successfully fetched the webpage for -> Suriname https://www.speedtest.net/global-index/suriname#mobile
# Successfully fetched the webpage for -> Thailand https://www.speedtest.net/global-index/thailand#mobile
# Successfully fetched the webpage for -> Israel https://www.speedtest.net/global-index/israel#mobile
# Successfully fetched the webpage for -> Botswana https://www.speedtest.net/global-index/botswana#mobile
# Successfully fetched the webpage for -> Morocco https://www.speedtest.net/global-index/morocco#mobile
# Successfully fetched the webpage for -> Kosovo https://www.speedtest.net/global-index/kosovo#mobile
# Successfully fetched the webpage for -> Georgia https://www.speedtest.net/global-index/georgia#mobile
# Successfully fetched the webpage for -> Kazakhstan https://www.speedtest.net/global-index/kazakhstan#mobile
# Successfully fetched the webpage for -> Côte d'Ivoire https://www.speedtest.net/global-index/côte-d'ivoire#mobile
# Successfully fetched the webpage for -> Turkey https://www.speedtest.net/global-index/turkey#mobile
# Successfully fetched the webpage for -> Chile https://www.speedtest.net/global-index/chile#mobile
# Successfully fetched the webpage for -> Ireland https://www.speedtest.net/global-index/ireland#mobile
# Successfully fetched the webpage for -> Iran https://www.speedtest.net/global-index/iran#mobile
# Successfully fetched the webpage for -> Burkina Faso https://www.speedtest.net/global-index/burkina-faso#mobile
# Successfully fetched the webpage for -> Lebanon https://www.speedtest.net/global-index/lebanon#mobile
# Successfully fetched the webpage for -> Senegal https://www.speedtest.net/global-index/senegal#mobile
# Successfully fetched the webpage for -> Zimbabwe https://www.speedtest.net/global-index/zimbabwe#mobile
# Successfully fetched the webpage for -> Moldova https://www.speedtest.net/global-index/moldova#mobile
# Successfully fetched the webpage for -> Ethiopia https://www.speedtest.net/global-index/ethiopia#mobile
# Successfully fetched the webpage for -> Guatemala https://www.speedtest.net/global-index/guatemala#mobile
# Successfully fetched the webpage for -> Trinidad and Tobago https://www.speedtest.net/global-index/trinidad-and-tobago#mobile
# Successfully fetched the webpage for -> Philippines https://www.speedtest.net/global-index/philippines#mobile
# Successfully fetched the webpage for -> Iraq https://www.speedtest.net/global-index/iraq#mobile
# Successfully fetched the webpage for -> Costa Rica https://www.speedtest.net/global-index/costa-rica#mobile
# Successfully fetched the webpage for -> Kyrgyzstan https://www.speedtest.net/global-index/kyrgyzstan#mobile
# Successfully fetched the webpage for -> El Salvador https://www.speedtest.net/global-index/el-salvador#mobile
# Successfully fetched the webpage for -> Armenia https://www.speedtest.net/global-index/armenia#mobile
# Successfully fetched the webpage for -> Dominican Republic https://www.speedtest.net/global-index/dominican-republic#mobile
# Successfully fetched the webpage for -> Honduras https://www.speedtest.net/global-index/honduras#mobile
# Successfully fetched the webpage for -> Benin https://www.speedtest.net/global-index/benin#mobile
# Successfully fetched the webpage for -> Uzbekistan https://www.speedtest.net/global-index/uzbekistan#mobile
# Successfully fetched the webpage for -> Uganda https://www.speedtest.net/global-index/uganda#mobile
# Successfully fetched the webpage for -> Mexico https://www.speedtest.net/global-index/mexico#mobile
# Successfully fetched the webpage for -> Argentina https://www.speedtest.net/global-index/argentina#mobile
# Successfully fetched the webpage for -> Jamaica https://www.speedtest.net/global-index/jamaica#mobile
# Successfully fetched the webpage for -> Nigeria https://www.speedtest.net/global-index/nigeria#mobile
# Successfully fetched the webpage for -> Egypt https://www.speedtest.net/global-index/egypt#mobile
# Successfully fetched the webpage for -> Ecuador https://www.speedtest.net/global-index/ecuador#mobile
# Successfully fetched the webpage for -> Tunisia https://www.speedtest.net/global-index/tunisia#mobile
# Successfully fetched the webpage for -> Ukraine https://www.speedtest.net/global-index/ukraine#mobile
# Successfully fetched the webpage for -> Indonesia https://www.speedtest.net/global-index/indonesia#mobile
# Successfully fetched the webpage for -> Myanmar (Burma) https://www.speedtest.net/global-index/myanmar-(burma)#mobile
# Successfully fetched the webpage for -> Laos https://www.speedtest.net/global-index/laos#mobile
# Successfully fetched the webpage for -> Bosnia and Herzegovina https://www.speedtest.net/global-index/bosnia-and-herzegovina#mobile
# Successfully fetched the webpage for -> Jordan https://www.speedtest.net/global-index/jordan#mobile
# Successfully fetched the webpage for -> Cambodia https://www.speedtest.net/global-index/cambodia#mobile
# Successfully fetched the webpage for -> Algeria https://www.speedtest.net/global-index/algeria#mobile
# Successfully fetched the webpage for -> Tanzania https://www.speedtest.net/global-index/tanzania#mobile
# Successfully fetched the webpage for -> Russia https://www.speedtest.net/global-index/russia#mobile
# Successfully fetched the webpage for -> Bangladesh https://www.speedtest.net/global-index/bangladesh#mobile
# Successfully fetched the webpage for -> Kenya https://www.speedtest.net/global-index/kenya#mobile
# Successfully fetched the webpage for -> Fiji https://www.speedtest.net/global-index/fiji#mobile
# Successfully fetched the webpage for -> Namibia https://www.speedtest.net/global-index/namibia#mobile
# Successfully fetched the webpage for -> Guyana https://www.speedtest.net/global-index/guyana#mobile
# Successfully fetched the webpage for -> Zambia https://www.speedtest.net/global-index/zambia#mobile
# Successfully fetched the webpage for -> Rwanda https://www.speedtest.net/global-index/rwanda#mobile
# Successfully fetched the webpage for -> Somalia https://www.speedtest.net/global-index/somalia#mobile
# Successfully fetched the webpage for -> Panama https://www.speedtest.net/global-index/panama#mobile
# Successfully fetched the webpage for -> Ghana https://www.speedtest.net/global-index/ghana#mobile
# Successfully fetched the webpage for -> Colombia https://www.speedtest.net/global-index/colombia#mobile
# Successfully fetched the webpage for -> Sri Lanka https://www.speedtest.net/global-index/sri-lanka#mobile
# Successfully fetched the webpage for -> Paraguay https://www.speedtest.net/global-index/paraguay#mobile
# Successfully fetched the webpage for -> Papua New Guinea https://www.speedtest.net/global-index/papua-new-guinea#mobile
# Successfully fetched the webpage for -> Peru https://www.speedtest.net/global-index/peru#mobile
# Successfully fetched the webpage for -> Pakistan https://www.speedtest.net/global-index/pakistan#mobile
# Successfully fetched the webpage for -> DR Congo https://www.speedtest.net/global-index/dr-congo#mobile
# Successfully fetched the webpage for -> Mozambique https://www.speedtest.net/global-index/mozambique#mobile
# Successfully fetched the webpage for -> Libya https://www.speedtest.net/global-index/libya#mobile
# Successfully fetched the webpage for -> Angola https://www.speedtest.net/global-index/angola#mobile
# Successfully fetched the webpage for -> Cameroon https://www.speedtest.net/global-index/cameroon#mobile
# Successfully fetched the webpage for -> Nicaragua https://www.speedtest.net/global-index/nicaragua#mobile
# Successfully fetched the webpage for -> Madagascar https://www.speedtest.net/global-index/madagascar#mobile
# Successfully fetched the webpage for -> Mongolia https://www.speedtest.net/global-index/mongolia#mobile
# Successfully fetched the webpage for -> Nepal https://www.speedtest.net/global-index/nepal#mobile
# Successfully fetched the webpage for -> Syria https://www.speedtest.net/global-index/syria#mobile
# Successfully fetched the webpage for -> Belarus https://www.speedtest.net/global-index/belarus#mobile
# Successfully fetched the webpage for -> Belize https://www.speedtest.net/global-index/belize#mobile
# Successfully fetched the webpage for -> Venezuela https://www.speedtest.net/global-index/venezuela#mobile
# Successfully fetched the webpage for -> Sudan https://www.speedtest.net/global-index/sudan#mobile
# Successfully fetched the webpage for -> Bolivia https://www.speedtest.net/global-index/bolivia#mobile
# Successfully fetched the webpage for -> Haiti https://www.speedtest.net/global-index/haiti#mobile
# Successfully fetched the webpage for -> Tajikistan https://www.speedtest.net/global-index/tajikistan#mobile
# Successfully fetched the webpage for -> Afghanistan https://www.speedtest.net/global-index/afghanistan#mobile
# Successfully fetched the webpage for -> Yemen https://www.speedtest.net/global-index/yemen#mobile
# Successfully fetched the webpage for -> East Timor https://www.speedtest.net/global-index/east-timor#mobile
# Successfully fetched the webpage for -> Cuba https://www.speedtest.net/global-index/cuba#mobile
# Successfully fetched the webpage for -> Ar-Rayyan https://www.speedtest.net/global-index/qatar?city=Ar-Rayyan#mobile
# Successfully fetched the webpage for -> Dubai https://www.speedtest.net/global-index/united-arab-emirates?city=Dubai#mobile
# Successfully fetched the webpage for -> Abu Dhabi https://www.speedtest.net/global-index/united-arab-emirates?city=Abu Dhabi#mobile
# Successfully fetched the webpage for -> Doha https://www.speedtest.net/global-index/qatar?city=Doha#mobile
# Successfully fetched the webpage for -> Riyadh https://www.speedtest.net/global-index/saudi-arabia?city=Riyadh#mobile
# Successfully fetched the webpage for -> Copenhagen https://www.speedtest.net/global-index/denmark?city=Copenhagen#mobile
# Successfully fetched the webpage for -> Lisbon https://www.speedtest.net/global-index/portugal?city=Lisbon#mobile
# Successfully fetched the webpage for -> Oslo https://www.speedtest.net/global-index/norway?city=Oslo#mobile
# Successfully fetched the webpage for -> Stockholm https://www.speedtest.net/global-index/sweden?city=Stockholm#mobile
# Successfully fetched the webpage for -> Porto https://www.speedtest.net/global-index/portugal?city=Porto#mobile
# Successfully fetched the webpage for -> Shanghai https://www.speedtest.net/global-index/china?city=Shanghai#mobile
# Successfully fetched the webpage for -> Kuwait City https://www.speedtest.net/global-index/kuwait?city=Kuwait City#mobile
# Successfully fetched the webpage for -> Beijing https://www.speedtest.net/global-index/china?city=Beijing#mobile
# Successfully fetched the webpage for -> Seoul https://www.speedtest.net/global-index/south-korea?city=Seoul#mobile
# Successfully fetched the webpage for -> Los Angeles https://www.speedtest.net/global-index/united-states?city=Los Angeles#mobile
# Successfully fetched the webpage for -> Sofia https://www.speedtest.net/global-index/bulgaria?city=Sofia#mobile
# Successfully fetched the webpage for -> Antwerp https://www.speedtest.net/global-index/belgium?city=Antwerp#mobile
# Successfully fetched the webpage for -> New York https://www.speedtest.net/global-index/united-states?city=New York#mobile
# Successfully fetched the webpage for -> Skopje https://www.speedtest.net/global-index/north-macedonia?city=Skopje#mobile
# Successfully fetched the webpage for -> Helsinki https://www.speedtest.net/global-index/finland?city=Helsinki#mobile
# Successfully fetched the webpage for -> Jeddah https://www.speedtest.net/global-index/saudi-arabia?city=Jeddah#mobile
# Successfully fetched the webpage for -> Vilnius https://www.speedtest.net/global-index/lithuania?city=Vilnius#mobile
# Successfully fetched the webpage for -> Gothenburg https://www.speedtest.net/global-index/sweden?city=Gothenburg#mobile
# Successfully fetched the webpage for -> Lyon https://www.speedtest.net/global-index/france?city=Lyon#mobile
# Successfully fetched the webpage for -> Johor Bahru https://www.speedtest.net/global-index/malaysia?city=Johor Bahru#mobile
# Successfully fetched the webpage for -> Paris https://www.speedtest.net/global-index/france?city=Paris#mobile
# Successfully fetched the webpage for -> Toronto https://www.speedtest.net/global-index/canada?city=Toronto#mobile
# Successfully fetched the webpage for -> Zagreb https://www.speedtest.net/global-index/croatia?city=Zagreb#mobile
# Successfully fetched the webpage for -> Busan https://www.speedtest.net/global-index/south-korea?city=Busan#mobile
# Successfully fetched the webpage for -> Kuala Lumpur https://www.speedtest.net/global-index/malaysia?city=Kuala Lumpur#mobile
# Successfully fetched the webpage for -> Montreal https://www.speedtest.net/global-index/canada?city=Montreal#mobile
# Successfully fetched the webpage for -> Zürich https://www.speedtest.net/global-index/switzerland?city=Zürich#mobile
# Successfully fetched the webpage for -> Riga https://www.speedtest.net/global-index/latvia?city=Riga#mobile
# Successfully fetched the webpage for -> Rotterdam https://www.speedtest.net/global-index/netherlands?city=Rotterdam#mobile
# Successfully fetched the webpage for -> São Paulo https://www.speedtest.net/global-index/brazil?city=São Paulo#mobile
# Successfully fetched the webpage for -> Manama https://www.speedtest.net/global-index/bahrain?city=Manama#mobile
# Successfully fetched the webpage for -> Delhi https://www.speedtest.net/global-index/india?city=Delhi#mobile
# Successfully fetched the webpage for -> Sydney https://www.speedtest.net/global-index/australia?city=Sydney#mobile
# Successfully fetched the webpage for -> Thessaloniki https://www.speedtest.net/global-index/greece?city=Thessaloniki#mobile
# Successfully fetched the webpage for -> Melbourne (Greater) https://www.speedtest.net/global-index/australia?city=Melbourne (Greater)#mobile
# Successfully fetched the webpage for -> Montevideo https://www.speedtest.net/global-index/uruguay?city=Montevideo#mobile
# Successfully fetched the webpage for -> Prague https://www.speedtest.net/global-index/czechia?city=Prague#mobile
# Successfully fetched the webpage for -> Amsterdam https://www.speedtest.net/global-index/netherlands?city=Amsterdam#mobile
# Successfully fetched the webpage for -> Warsaw https://www.speedtest.net/global-index/poland?city=Warsaw#mobile
# Successfully fetched the webpage for -> Rio de Janeiro https://www.speedtest.net/global-index/brazil?city=Rio de Janeiro#mobile
# Successfully fetched the webpage for -> Muscat https://www.speedtest.net/global-index/oman?city=Muscat#mobile
# Successfully fetched the webpage for -> Hamburg https://www.speedtest.net/global-index/germany?city=Hamburg#mobile
# Successfully fetched the webpage for -> Taipei https://www.speedtest.net/global-index/taiwan?city=Taipei#mobile
# Successfully fetched the webpage for -> Vienna https://www.speedtest.net/global-index/austria?city=Vienna#mobile
# Successfully fetched the webpage for -> Manchester https://www.speedtest.net/global-index/united-kingdom?city=Manchester#mobile
# Successfully fetched the webpage for -> Berlin https://www.speedtest.net/global-index/germany?city=Berlin#mobile
# Successfully fetched the webpage for -> Kraków https://www.speedtest.net/global-index/poland?city=Kraków#mobile
# Successfully fetched the webpage for -> Athens https://www.speedtest.net/global-index/greece?city=Athens#mobile
# Successfully fetched the webpage for -> Bucharest https://www.speedtest.net/global-index/romania?city=Bucharest#mobile
# Successfully fetched the webpage for -> Geneva https://www.speedtest.net/global-index/switzerland?city=Geneva#mobile
# Successfully fetched the webpage for -> London https://www.speedtest.net/global-index/united-kingdom?city=London#mobile
# Successfully fetched the webpage for -> Dublin https://www.speedtest.net/global-index/ireland?city=Dublin#mobile
# Successfully fetched the webpage for -> Brussels https://www.speedtest.net/global-index/belgium?city=Brussels#mobile
# Successfully fetched the webpage for -> Madrid https://www.speedtest.net/global-index/spain?city=Madrid#mobile
# Successfully fetched the webpage for -> Auckland https://www.speedtest.net/global-index/new-zealand?city=Auckland#mobile
# Successfully fetched the webpage for -> New Taipei https://www.speedtest.net/global-index/taiwan?city=New Taipei#mobile
# Successfully fetched the webpage for -> Barcelona https://www.speedtest.net/global-index/spain?city=Barcelona#mobile
# Successfully fetched the webpage for -> Milan https://www.speedtest.net/global-index/italy?city=Milan#mobile
# Successfully fetched the webpage for -> Tel Aviv-Yafo https://www.speedtest.net/global-index/israel?city=Tel Aviv-Yafo#mobile
# Successfully fetched the webpage for -> Mumbai https://www.speedtest.net/global-index/india?city=Mumbai#mobile
# Successfully fetched the webpage for -> Budapest https://www.speedtest.net/global-index/hungary?city=Budapest#mobile
# Successfully fetched the webpage for -> Osaka https://www.speedtest.net/global-index/japan?city=Osaka#mobile
# Successfully fetched the webpage for -> Johannesburg https://www.speedtest.net/global-index/south-africa?city=Johannesburg#mobile
# Successfully fetched the webpage for -> Bangkok https://www.speedtest.net/global-index/thailand?city=Bangkok#mobile
# Successfully fetched the webpage for -> Almaty https://www.speedtest.net/global-index/kazakhstan?city=Almaty#mobile
# Successfully fetched the webpage for -> Belgrade https://www.speedtest.net/global-index/serbia?city=Belgrade#mobile
# Successfully fetched the webpage for -> Rome https://www.speedtest.net/global-index/italy?city=Rome#mobile
# Successfully fetched the webpage for -> Guatemala City https://www.speedtest.net/global-index/guatemala?city=Guatemala City#mobile
# Successfully fetched the webpage for -> Baku https://www.speedtest.net/global-index/azerbaijan?city=Baku#mobile
# Successfully fetched the webpage for -> Rabat https://www.speedtest.net/global-index/morocco?city=Rabat#mobile
# Successfully fetched the webpage for -> Cape Town https://www.speedtest.net/global-index/south-africa?city=Cape Town#mobile
# Successfully fetched the webpage for -> Santiago https://www.speedtest.net/global-index/chile?city=Santiago#mobile
# Successfully fetched the webpage for -> Casablanca https://www.speedtest.net/global-index/morocco?city=Casablanca#mobile
# Successfully fetched the webpage for -> Tokyo https://www.speedtest.net/global-index/japan?city=Tokyo#mobile
# Successfully fetched the webpage for -> Ho Chi Minh City https://www.speedtest.net/global-index/vietnam?city=Ho Chi Minh City#mobile
# Successfully fetched the webpage for -> Santo Domingo https://www.speedtest.net/global-index/dominican-republic?city=Santo Domingo#mobile
# Successfully fetched the webpage for -> Beirut https://www.speedtest.net/global-index/lebanon?city=Beirut#mobile
# Successfully fetched the webpage for -> Addis Ababa https://www.speedtest.net/global-index/ethiopia?city=Addis Ababa#mobile
# Successfully fetched the webpage for -> Haifa https://www.speedtest.net/global-index/israel?city=Haifa#mobile
# Successfully fetched the webpage for -> Manila https://www.speedtest.net/global-index/philippines?city=Manila#mobile
# Successfully fetched the webpage for -> Astana https://www.speedtest.net/global-index/kazakhstan?city=Astana#mobile
# Successfully fetched the webpage for -> Lagos https://www.speedtest.net/global-index/nigeria?city=Lagos#mobile
# Successfully fetched the webpage for -> Istanbul https://www.speedtest.net/global-index/turkey?city=Istanbul#mobile
# Successfully fetched the webpage for -> Colombo https://www.speedtest.net/global-index/sri-lanka?city=Colombo#mobile
# Successfully fetched the webpage for -> Ankara https://www.speedtest.net/global-index/turkey?city=Ankara#mobile
# Successfully fetched the webpage for -> Abidjan https://www.speedtest.net/global-index/côte-d'ivoire?city=Abidjan#mobile
# Successfully fetched the webpage for -> Chon Buri https://www.speedtest.net/global-index/thailand?city=Chon Buri#mobile
# Successfully fetched the webpage for -> Tashkent https://www.speedtest.net/global-index/uzbekistan?city=Tashkent#mobile
# Successfully fetched the webpage for -> Hanoi https://www.speedtest.net/global-index/vietnam?city=Hanoi#mobile
# Successfully fetched the webpage for -> San Pedro Sula https://www.speedtest.net/global-index/honduras?city=San Pedro Sula#mobile
# Successfully fetched the webpage for -> Tbilisi https://www.speedtest.net/global-index/georgia?city=Tbilisi#mobile
# Successfully fetched the webpage for -> Medellín https://www.speedtest.net/global-index/colombia?city=Medellín#mobile
# Successfully fetched the webpage for -> Davao City https://www.speedtest.net/global-index/philippines?city=Davao City#mobile
# Successfully fetched the webpage for -> Moscow https://www.speedtest.net/global-index/russia?city=Moscow#mobile
# Successfully fetched the webpage for -> Tehran https://www.speedtest.net/global-index/iran?city=Tehran#mobile
# Successfully fetched the webpage for -> Yangon https://www.speedtest.net/global-index/myanmar-(burma)?city=Yangon#mobile
# Successfully fetched the webpage for -> Guadalajara https://www.speedtest.net/global-index/mexico?city=Guadalajara#mobile
# Successfully fetched the webpage for -> Chisinau https://www.speedtest.net/global-index/moldova?city=Chisinau#mobile
# Successfully fetched the webpage for -> Buenos Aires https://www.speedtest.net/global-index/argentina?city=Buenos Aires#mobile
# Successfully fetched the webpage for -> Mandalay https://www.speedtest.net/global-index/myanmar-(burma)?city=Mandalay#mobile
# Successfully fetched the webpage for -> Samarkand https://www.speedtest.net/global-index/uzbekistan?city=Samarkand#mobile
# Successfully fetched the webpage for -> Kampala https://www.speedtest.net/global-index/uganda?city=Kampala#mobile
# Successfully fetched the webpage for -> Amman https://www.speedtest.net/global-index/jordan?city=Amman#mobile
# Successfully fetched the webpage for -> Córdoba https://www.speedtest.net/global-index/argentina?city=Córdoba#mobile
# Successfully fetched the webpage for -> Mashhad https://www.speedtest.net/global-index/iran?city=Mashhad#mobile
# Successfully fetched the webpage for -> Valparaíso https://www.speedtest.net/global-index/chile?city=Valparaíso#mobile
# Successfully fetched the webpage for -> Nairobi https://www.speedtest.net/global-index/kenya?city=Nairobi#mobile
# Successfully fetched the webpage for -> South Jakarta https://www.speedtest.net/global-index/indonesia?city=South Jakarta#mobile
# Successfully fetched the webpage for -> Bishkek https://www.speedtest.net/global-index/kyrgyzstan?city=Bishkek#mobile
# Successfully fetched the webpage for -> Chittagong https://www.speedtest.net/global-index/bangladesh?city=Chittagong#mobile
# Successfully fetched the webpage for -> Mosul https://www.speedtest.net/global-index/iraq?city=Mosul#mobile
# Successfully fetched the webpage for -> Baghdad https://www.speedtest.net/global-index/iraq?city=Baghdad#mobile
# Successfully fetched the webpage for -> Mexico City https://www.speedtest.net/global-index/mexico?city=Mexico City#mobile
# Successfully fetched the webpage for -> Santiago De Los Caballeros https://www.speedtest.net/global-index/dominican-republic?city=Santiago De Los Caballeros#mobile
# Successfully fetched the webpage for -> San José https://www.speedtest.net/global-index/costa-rica?city=San José#mobile
# Successfully fetched the webpage for -> Oran https://www.speedtest.net/global-index/algeria?city=Oran#mobile
# Successfully fetched the webpage for -> Kiev https://www.speedtest.net/global-index/ukraine?city=Kiev#mobile
# Successfully fetched the webpage for -> Bogotá https://www.speedtest.net/global-index/colombia?city=Bogotá#mobile
# Successfully fetched the webpage for -> Vientiane https://www.speedtest.net/global-index/laos?city=Vientiane#mobile
# Successfully fetched the webpage for -> Dar es Salaam https://www.speedtest.net/global-index/tanzania?city=Dar es Salaam#mobile
# Successfully fetched the webpage for -> Az-Zarqa https://www.speedtest.net/global-index/jordan?city=Az-Zarqa#mobile
# Successfully fetched the webpage for -> Sfax https://www.speedtest.net/global-index/tunisia?city=Sfax#mobile
# Successfully fetched the webpage for -> Yerevan https://www.speedtest.net/global-index/armenia?city=Yerevan#mobile
# Successfully fetched the webpage for -> Phnom Penh https://www.speedtest.net/global-index/cambodia?city=Phnom Penh#mobile
# Successfully fetched the webpage for -> Tunis https://www.speedtest.net/global-index/tunisia?city=Tunis#mobile
# Successfully fetched the webpage for -> Dhaka https://www.speedtest.net/global-index/bangladesh?city=Dhaka#mobile
# Successfully fetched the webpage for -> Algiers https://www.speedtest.net/global-index/algeria?city=Algiers#mobile
# Successfully fetched the webpage for -> San Salvador https://www.speedtest.net/global-index/el-salvador?city=San Salvador#mobile
# Successfully fetched the webpage for -> Bekasi https://www.speedtest.net/global-index/indonesia?city=Bekasi#mobile
# Successfully fetched the webpage for -> Saint Petersburg https://www.speedtest.net/global-index/russia?city=Saint Petersburg#mobile
# Successfully fetched the webpage for -> Guayaquil https://www.speedtest.net/global-index/ecuador?city=Guayaquil#mobile
# Successfully fetched the webpage for -> Cairo https://www.speedtest.net/global-index/egypt?city=Cairo#mobile
# Successfully fetched the webpage for -> Tegucigalpa https://www.speedtest.net/global-index/honduras?city=Tegucigalpa#mobile
# Successfully fetched the webpage for -> Lusaka https://www.speedtest.net/global-index/zambia?city=Lusaka#mobile
# Successfully fetched the webpage for -> Kharkiv https://www.speedtest.net/global-index/ukraine?city=Kharkiv#mobile
# Successfully fetched the webpage for -> Accra https://www.speedtest.net/global-index/ghana?city=Accra#mobile
# Successfully fetched the webpage for -> Quito https://www.speedtest.net/global-index/ecuador?city=Quito#mobile
# Successfully fetched the webpage for -> Alexandria https://www.speedtest.net/global-index/egypt?city=Alexandria#mobile
# Successfully fetched the webpage for -> Maputo https://www.speedtest.net/global-index/mozambique?city=Maputo#mobile
# Successfully fetched the webpage for -> Damascus https://www.speedtest.net/global-index/syria?city=Damascus#mobile
# Successfully fetched the webpage for -> Kinshasa https://www.speedtest.net/global-index/dr-congo?city=Kinshasa#mobile
# Successfully fetched the webpage for -> Lahore https://www.speedtest.net/global-index/pakistan?city=Lahore#mobile
# Successfully fetched the webpage for -> Douala https://www.speedtest.net/global-index/cameroon?city=Douala#mobile
# Successfully fetched the webpage for -> Lima https://www.speedtest.net/global-index/peru?city=Lima#mobile
# Successfully fetched the webpage for -> Panama City https://www.speedtest.net/global-index/panama?city=Panama City#mobile
# Successfully fetched the webpage for -> Misrata https://www.speedtest.net/global-index/libya?city=Misrata#mobile
# Successfully fetched the webpage for -> Tripoli https://www.speedtest.net/global-index/libya?city=Tripoli#mobile
# Successfully fetched the webpage for -> Karachi https://www.speedtest.net/global-index/pakistan?city=Karachi#mobile
# Successfully fetched the webpage for -> Minsk https://www.speedtest.net/global-index/belarus?city=Minsk#mobile
# Successfully fetched the webpage for -> Managua https://www.speedtest.net/global-index/nicaragua?city=Managua#mobile
# Successfully fetched the webpage for -> Luanda https://www.speedtest.net/global-index/angola?city=Luanda#mobile
# Successfully fetched the webpage for -> Aleppo https://www.speedtest.net/global-index/syria?city=Aleppo#mobile
# Successfully fetched the webpage for -> Asuncion https://www.speedtest.net/global-index/paraguay?city=Asuncion#mobile
# Successfully fetched the webpage for -> Arequipa https://www.speedtest.net/global-index/peru?city=Arequipa#mobile
# Successfully fetched the webpage for -> Caracas https://www.speedtest.net/global-index/venezuela?city=Caracas#mobile
# Successfully fetched the webpage for -> Ulaanbaatar https://www.speedtest.net/global-index/mongolia?city=Ulaanbaatar#mobile
# Successfully fetched the webpage for -> Dushanbe https://www.speedtest.net/global-index/tajikistan?city=Dushanbe#mobile
# Successfully fetched the webpage for -> Santa Cruz de la Sierra https://www.speedtest.net/global-index/bolivia?city=Santa Cruz de la Sierra#mobile
# Successfully fetched the webpage for -> Sana'a https://www.speedtest.net/global-index/yemen?city=Sana'a#mobile
# Successfully fetched the webpage for -> Gomel https://www.speedtest.net/global-index/belarus?city=Gomel#mobile
# Successfully fetched the webpage for -> La Paz https://www.speedtest.net/global-index/bolivia?city=La Paz#mobile
# Successfully fetched the webpage for -> Kabul https://www.speedtest.net/global-index/afghanistan?city=Kabul#mobile
# Successfully fetched the webpage for -> Havana https://www.speedtest.net/global-index/cuba?city=Havana#mobile
# Successfully fetched the webpage for -> Singapore https://www.speedtest.net/global-index/singapore#fixed
# Successfully fetched the webpage for -> United Arab Emirates https://www.speedtest.net/global-index/united-arab-emirates#fixed
# Successfully fetched the webpage for -> Hong Kong (SAR) https://www.speedtest.net/global-index/hong-kong-(sar)#fixed
# Successfully fetched the webpage for -> Chile https://www.speedtest.net/global-index/chile#fixed
# Successfully fetched the webpage for -> United States https://www.speedtest.net/global-index/united-states#fixed
# Successfully fetched the webpage for -> Iceland https://www.speedtest.net/global-index/iceland#fixed
# Successfully fetched the webpage for -> France https://www.speedtest.net/global-index/france#fixed
# Successfully fetched the webpage for -> China https://www.speedtest.net/global-index/china#fixed
# Successfully fetched the webpage for -> Monaco https://www.speedtest.net/global-index/monaco#fixed
# Successfully fetched the webpage for -> Thailand https://www.speedtest.net/global-index/thailand#fixed
# Successfully fetched the webpage for -> Denmark https://www.speedtest.net/global-index/denmark#fixed
# Successfully fetched the webpage for -> Spain https://www.speedtest.net/global-index/spain#fixed
# Successfully fetched the webpage for -> Romania https://www.speedtest.net/global-index/romania#fixed
# Successfully fetched the webpage for -> Switzerland https://www.speedtest.net/global-index/switzerland#fixed
# Successfully fetched the webpage for -> Israel https://www.speedtest.net/global-index/israel#fixed
# Successfully fetched the webpage for -> Canada https://www.speedtest.net/global-index/canada#fixed
# Successfully fetched the webpage for -> Japan https://www.speedtest.net/global-index/japan#fixed
# Successfully fetched the webpage for -> Netherlands https://www.speedtest.net/global-index/netherlands#fixed
# Successfully fetched the webpage for -> Liechtenstein https://www.speedtest.net/global-index/liechtenstein#fixed
# Successfully fetched the webpage for -> Hungary https://www.speedtest.net/global-index/hungary#fixed
# Successfully fetched the webpage for -> Portugal https://www.speedtest.net/global-index/portugal#fixed
# Successfully fetched the webpage for -> Kuwait https://www.speedtest.net/global-index/kuwait#fixed
# Successfully fetched the webpage for -> Taiwan https://www.speedtest.net/global-index/taiwan#fixed
# Successfully fetched the webpage for -> New Zealand https://www.speedtest.net/global-index/new-zealand#fixed
# Successfully fetched the webpage for -> South Korea https://www.speedtest.net/global-index/south-korea#fixed
# Successfully fetched the webpage for -> Macau (SAR) https://www.speedtest.net/global-index/macau-(sar)#fixed
# Successfully fetched the webpage for -> Brazil https://www.speedtest.net/global-index/brazil#fixed
# Successfully fetched the webpage for -> Poland https://www.speedtest.net/global-index/poland#fixed
# Successfully fetched the webpage for -> Qatar https://www.speedtest.net/global-index/qatar#fixed
# Successfully fetched the webpage for -> Sweden https://www.speedtest.net/global-index/sweden#fixed
# Successfully fetched the webpage for -> Panama https://www.speedtest.net/global-index/panama#fixed
# Successfully fetched the webpage for -> Luxembourg https://www.speedtest.net/global-index/luxembourg#fixed
# Successfully fetched the webpage for -> Jordan https://www.speedtest.net/global-index/jordan#fixed
# Successfully fetched the webpage for -> Peru https://www.speedtest.net/global-index/peru#fixed
# Successfully fetched the webpage for -> Moldova https://www.speedtest.net/global-index/moldova#fixed
# Successfully fetched the webpage for -> Colombia https://www.speedtest.net/global-index/colombia#fixed
# Successfully fetched the webpage for -> Uruguay https://www.speedtest.net/global-index/uruguay#fixed
# Successfully fetched the webpage for -> Norway https://www.speedtest.net/global-index/norway#fixed
# Successfully fetched the webpage for -> Andorra https://www.speedtest.net/global-index/andorra#fixed
# Successfully fetched the webpage for -> Lithuania https://www.speedtest.net/global-index/lithuania#fixed
# Successfully fetched the webpage for -> Trinidad and Tobago https://www.speedtest.net/global-index/trinidad-and-tobago#fixed
# Successfully fetched the webpage for -> Ireland https://www.speedtest.net/global-index/ireland#fixed
# Successfully fetched the webpage for -> Finland https://www.speedtest.net/global-index/finland#fixed
# Successfully fetched the webpage for -> Malta https://www.speedtest.net/global-index/malta#fixed
# Successfully fetched the webpage for -> Malaysia https://www.speedtest.net/global-index/malaysia#fixed
# Successfully fetched the webpage for -> Saudi Arabia https://www.speedtest.net/global-index/saudi-arabia#fixed
# Successfully fetched the webpage for -> Vietnam https://www.speedtest.net/global-index/vietnam#fixed
# Successfully fetched the webpage for -> United Kingdom https://www.speedtest.net/global-index/united-kingdom#fixed
# Successfully fetched the webpage for -> San Marino https://www.speedtest.net/global-index/san-marino#fixed
# Successfully fetched the webpage for -> Saint Lucia https://www.speedtest.net/global-index/saint-lucia#fixed
# Successfully fetched the webpage for -> Belgium https://www.speedtest.net/global-index/belgium#fixed
# Successfully fetched the webpage for -> Philippines https://www.speedtest.net/global-index/philippines#fixed
# Successfully fetched the webpage for -> Austria https://www.speedtest.net/global-index/austria#fixed
# Successfully fetched the webpage for -> Slovenia https://www.speedtest.net/global-index/slovenia#fixed
# Successfully fetched the webpage for -> Dominica https://www.speedtest.net/global-index/dominica#fixed
# Successfully fetched the webpage for -> Costa Rica https://www.speedtest.net/global-index/costa-rica#fixed
# Successfully fetched the webpage for -> Latvia https://www.speedtest.net/global-index/latvia#fixed
# Successfully fetched the webpage for -> Germany https://www.speedtest.net/global-index/germany#fixed
# Successfully fetched the webpage for -> Saint Vincent and the Grenadines https://www.speedtest.net/global-index/saint-vincent-and-the-grenadines#fixed
# Successfully fetched the webpage for -> Cyprus https://www.speedtest.net/global-index/cyprus#fixed
# Successfully fetched the webpage for -> Ecuador https://www.speedtest.net/global-index/ecuador#fixed
# Successfully fetched the webpage for -> Paraguay https://www.speedtest.net/global-index/paraguay#fixed
# Successfully fetched the webpage for -> Bahrain https://www.speedtest.net/global-index/bahrain#fixed
# Successfully fetched the webpage for -> Montenegro https://www.speedtest.net/global-index/montenegro#fixed
# Successfully fetched the webpage for -> Russia https://www.speedtest.net/global-index/russia#fixed
# Successfully fetched the webpage for -> Barbados https://www.speedtest.net/global-index/barbados#fixed
# Successfully fetched the webpage for -> Grenada https://www.speedtest.net/global-index/grenada#fixed
# Successfully fetched the webpage for -> Guyana https://www.speedtest.net/global-index/guyana#fixed
# Successfully fetched the webpage for -> Estonia https://www.speedtest.net/global-index/estonia#fixed
# Successfully fetched the webpage for -> Serbia https://www.speedtest.net/global-index/serbia#fixed
# Successfully fetched the webpage for -> Italy https://www.speedtest.net/global-index/italy#fixed
# Successfully fetched the webpage for -> Bulgaria https://www.speedtest.net/global-index/bulgaria#fixed
# Successfully fetched the webpage for -> Argentina https://www.speedtest.net/global-index/argentina#fixed
# Successfully fetched the webpage for -> Brunei https://www.speedtest.net/global-index/brunei#fixed
# Successfully fetched the webpage for -> Slovakia https://www.speedtest.net/global-index/slovakia#fixed
# Successfully fetched the webpage for -> Ukraine https://www.speedtest.net/global-index/ukraine#fixed
# Successfully fetched the webpage for -> Kosovo https://www.speedtest.net/global-index/kosovo#fixed
# Successfully fetched the webpage for -> Croatia https://www.speedtest.net/global-index/croatia#fixed
# Successfully fetched the webpage for -> Jamaica https://www.speedtest.net/global-index/jamaica#fixed
# Successfully fetched the webpage for -> Czechia https://www.speedtest.net/global-index/czechia#fixed
# Successfully fetched the webpage for -> The Bahamas https://www.speedtest.net/global-index/the-bahamas#fixed
# Successfully fetched the webpage for -> Côte d'Ivoire https://www.speedtest.net/global-index/côte-d'ivoire#fixed
# Successfully fetched the webpage for -> Mongolia https://www.speedtest.net/global-index/mongolia#fixed
# Successfully fetched the webpage for -> Nepal https://www.speedtest.net/global-index/nepal#fixed
# Successfully fetched the webpage for -> Palestine https://www.speedtest.net/global-index/palestine#fixed
# Successfully fetched the webpage for -> Egypt https://www.speedtest.net/global-index/egypt#fixed
# Successfully fetched the webpage for -> Belarus https://www.speedtest.net/global-index/belarus#fixed
# Successfully fetched the webpage for -> Saint Kitts and Nevis https://www.speedtest.net/global-index/saint-kitts-and-nevis#fixed
# Successfully fetched the webpage for -> Mexico https://www.speedtest.net/global-index/mexico#fixed
# Successfully fetched the webpage for -> Uzbekistan https://www.speedtest.net/global-index/uzbekistan#fixed
# Successfully fetched the webpage for -> Oman https://www.speedtest.net/global-index/oman#fixed
# Successfully fetched the webpage for -> India https://www.speedtest.net/global-index/india#fixed
# Successfully fetched the webpage for -> Albania https://www.speedtest.net/global-index/albania#fixed
# Successfully fetched the webpage for -> Australia https://www.speedtest.net/global-index/australia#fixed
# Successfully fetched the webpage for -> Kyrgyzstan https://www.speedtest.net/global-index/kyrgyzstan#fixed
# Successfully fetched the webpage for -> Armenia https://www.speedtest.net/global-index/armenia#fixed
# Successfully fetched the webpage for -> Nicaragua https://www.speedtest.net/global-index/nicaragua#fixed
# Successfully fetched the webpage for -> Kazakhstan https://www.speedtest.net/global-index/kazakhstan#fixed
# Successfully fetched the webpage for -> Mauritius https://www.speedtest.net/global-index/mauritius#fixed
# Successfully fetched the webpage for -> El Salvador https://www.speedtest.net/global-index/el-salvador#fixed
# Successfully fetched the webpage for -> Guatemala https://www.speedtest.net/global-index/guatemala#fixed
# Successfully fetched the webpage for -> Greece https://www.speedtest.net/global-index/greece#fixed
# Successfully fetched the webpage for -> South Africa https://www.speedtest.net/global-index/south-africa#fixed
# Successfully fetched the webpage for -> Venezuela https://www.speedtest.net/global-index/venezuela#fixed
# Successfully fetched the webpage for -> Belize https://www.speedtest.net/global-index/belize#fixed
# Successfully fetched the webpage for -> Honduras https://www.speedtest.net/global-index/honduras#fixed
# Successfully fetched the webpage for -> Cambodia https://www.speedtest.net/global-index/cambodia#fixed
# Successfully fetched the webpage for -> Bangladesh https://www.speedtest.net/global-index/bangladesh#fixed
# Successfully fetched the webpage for -> Gabon https://www.speedtest.net/global-index/gabon#fixed
# Successfully fetched the webpage for -> Turkey https://www.speedtest.net/global-index/turkey#fixed
# Successfully fetched the webpage for -> Ghana https://www.speedtest.net/global-index/ghana#fixed
# Successfully fetched the webpage for -> Burkina Faso https://www.speedtest.net/global-index/burkina-faso#fixed
# Successfully fetched the webpage for -> North Macedonia https://www.speedtest.net/global-index/north-macedonia#fixed
# Successfully fetched the webpage for -> Congo https://www.speedtest.net/global-index/congo#fixed
# Successfully fetched the webpage for -> DR Congo https://www.speedtest.net/global-index/dr-congo#fixed
# Successfully fetched the webpage for -> Madagascar https://www.speedtest.net/global-index/madagascar#fixed
# Successfully fetched the webpage for -> Azerbaijan https://www.speedtest.net/global-index/azerbaijan#fixed
# Successfully fetched the webpage for -> Haiti https://www.speedtest.net/global-index/haiti#fixed
# Successfully fetched the webpage for -> Antigua and Barbuda https://www.speedtest.net/global-index/antigua-and-barbuda#fixed
# Successfully fetched the webpage for -> Dominican Republic https://www.speedtest.net/global-index/dominican-republic#fixed
# Successfully fetched the webpage for -> Laos https://www.speedtest.net/global-index/laos#fixed
# Successfully fetched the webpage for -> Iraq https://www.speedtest.net/global-index/iraq#fixed
# Successfully fetched the webpage for -> Bolivia https://www.speedtest.net/global-index/bolivia#fixed
# Successfully fetched the webpage for -> Togo https://www.speedtest.net/global-index/togo#fixed
# ...
# Successfully fetched the webpage for -> Oslo https://www.speedtest.net/global-index/norway?city=Oslo#fixed
# Successfully fetched the webpage for -> Zagreb https://www.speedtest.net/global-index/croatia?city=Zagreb#fixed
# Successfully fetched the webpage for -> Lisbon https://www.speedtest.net/global-index/portugal?city=Lisbon#fixed
# Successfully fetched the webpage for -> Buenos Aires https://www.speedtest.net/global-index/argentina?city=Buenos Aires#fixed
# Successfully fetched the webpage for -> London https://www.speedtest.net/global-index/united-kingdom?city=London#fixed
# Successfully fetched the webpage for -> Rome https://www.speedtest.net/global-index/italy?city=Rome#fixed
# Successfully fetched the webpage for -> Belgrade https://www.speedtest.net/global-index/serbia?city=Belgrade#fixed
# Successfully fetched the webpage for -> Busan https://www.speedtest.net/global-index/south-korea?city=Busan#fixed
# Successfully fetched the webpage for -> Kuala Lumpur https://www.speedtest.net/global-index/malaysia?city=Kuala Lumpur#fixed
# Successfully fetched the webpage for -> Riga https://www.speedtest.net/global-index/latvia?city=Riga#fixed
# Successfully fetched the webpage for -> Jeddah https://www.speedtest.net/global-index/saudi-arabia?city=Jeddah#fixed
# Successfully fetched the webpage for -> Hanoi https://www.speedtest.net/global-index/vietnam?city=Hanoi#fixed
# Successfully fetched the webpage for -> Helsinki https://www.speedtest.net/global-index/finland?city=Helsinki#fixed
# Successfully fetched the webpage for -> San José https://www.speedtest.net/global-index/costa-rica?city=San José#fixed
# Successfully fetched the webpage for -> Hamburg https://www.speedtest.net/global-index/germany?city=Hamburg#fixed
# Successfully fetched the webpage for -> Moscow https://www.speedtest.net/global-index/russia?city=Moscow#fixed
# Successfully fetched the webpage for -> Guayaquil https://www.speedtest.net/global-index/ecuador?city=Guayaquil#fixed
# Successfully fetched the webpage for -> Port of Spain https://www.speedtest.net/global-index/trinidad-and-tobago?city=Port of Spain#fixed
# Successfully fetched the webpage for -> Antwerp https://www.speedtest.net/global-index/belgium?city=Antwerp#fixed
# Successfully fetched the webpage for -> Berlin https://www.speedtest.net/global-index/germany?city=Berlin#fixed
# Successfully fetched the webpage for -> Kiev https://www.speedtest.net/global-index/ukraine?city=Kiev#fixed
# Successfully fetched the webpage for -> Davao City https://www.speedtest.net/global-index/philippines?city=Davao City#fixed
# Successfully fetched the webpage for -> Saint Petersburg https://www.speedtest.net/global-index/russia?city=Saint Petersburg#fixed
# Successfully fetched the webpage for -> Quito https://www.speedtest.net/global-index/ecuador?city=Quito#fixed
# Successfully fetched the webpage for -> Manila https://www.speedtest.net/global-index/philippines?city=Manila#fixed
# Successfully fetched the webpage for -> Maracaibo https://www.speedtest.net/global-index/venezuela?city=Maracaibo#fixed
# Successfully fetched the webpage for -> Asuncion https://www.speedtest.net/global-index/paraguay?city=Asuncion#fixed
# Successfully fetched the webpage for -> Brussels https://www.speedtest.net/global-index/belgium?city=Brussels#fixed
# Successfully fetched the webpage for -> Sofia https://www.speedtest.net/global-index/bulgaria?city=Sofia#fixed
# Successfully fetched the webpage for -> Manama https://www.speedtest.net/global-index/bahrain?city=Manama#fixed
# Successfully fetched the webpage for -> Kharkiv https://www.speedtest.net/global-index/ukraine?city=Kharkiv#fixed
# Successfully fetched the webpage for -> Córdoba https://www.speedtest.net/global-index/argentina?city=Córdoba#fixed
# Successfully fetched the webpage for -> Mexico City https://www.speedtest.net/global-index/mexico?city=Mexico City#fixed
# Successfully fetched the webpage for -> Delhi https://www.speedtest.net/global-index/india?city=Delhi#fixed
# Successfully fetched the webpage for -> Guadalajara https://www.speedtest.net/global-index/mexico?city=Guadalajara#fixed
# Successfully fetched the webpage for -> Prague https://www.speedtest.net/global-index/czechia?city=Prague#fixed
# Successfully fetched the webpage for -> Kathmandu https://www.speedtest.net/global-index/nepal?city=Kathmandu#fixed
# Successfully fetched the webpage for -> Minsk https://www.speedtest.net/global-index/belarus?city=Minsk#fixed
# Successfully fetched the webpage for -> Muscat https://www.speedtest.net/global-index/oman?city=Muscat#fixed
# Successfully fetched the webpage for -> Abidjan https://www.speedtest.net/global-index/côte-d'ivoire?city=Abidjan#fixed
# Successfully fetched the webpage for -> Alexandria https://www.speedtest.net/global-index/egypt?city=Alexandria#fixed
# Successfully fetched the webpage for -> Sydney https://www.speedtest.net/global-index/australia?city=Sydney#fixed
# Successfully fetched the webpage for -> Gomel https://www.speedtest.net/global-index/belarus?city=Gomel#fixed
# Successfully fetched the webpage for -> Melbourne (Greater) https://www.speedtest.net/global-index/australia?city=Melbourne (Greater)#fixed
# Successfully fetched the webpage for -> Kingston https://www.speedtest.net/global-index/jamaica?city=Kingston#fixed
# Successfully fetched the webpage for -> Ulaanbaatar https://www.speedtest.net/global-index/mongolia?city=Ulaanbaatar#fixed
# Successfully fetched the webpage for -> Yerevan https://www.speedtest.net/global-index/armenia?city=Yerevan#fixed
# Successfully fetched the webpage for -> Astana https://www.speedtest.net/global-index/kazakhstan?city=Astana#fixed
# Successfully fetched the webpage for -> Tashkent https://www.speedtest.net/global-index/uzbekistan?city=Tashkent#fixed
# Successfully fetched the webpage for -> Thessaloniki https://www.speedtest.net/global-index/greece?city=Thessaloniki#fixed
# Successfully fetched the webpage for -> Bishkek https://www.speedtest.net/global-index/kyrgyzstan?city=Bishkek#fixed
# Successfully fetched the webpage for -> Mumbai https://www.speedtest.net/global-index/india?city=Mumbai#fixed
# Successfully fetched the webpage for -> Johannesburg https://www.speedtest.net/global-index/south-africa?city=Johannesburg#fixed
# Successfully fetched the webpage for -> Almaty https://www.speedtest.net/global-index/kazakhstan?city=Almaty#fixed
# Successfully fetched the webpage for -> Guatemala City https://www.speedtest.net/global-index/guatemala?city=Guatemala City#fixed
# Successfully fetched the webpage for -> Santo Domingo https://www.speedtest.net/global-index/dominican-republic?city=Santo Domingo#fixed
# Successfully fetched the webpage for -> Samarkand https://www.speedtest.net/global-index/uzbekistan?city=Samarkand#fixed
# Successfully fetched the webpage for -> Cape Town https://www.speedtest.net/global-index/south-africa?city=Cape Town#fixed
# Successfully fetched the webpage for -> San Salvador https://www.speedtest.net/global-index/el-salvador?city=San Salvador#fixed
# Successfully fetched the webpage for -> Managua https://www.speedtest.net/global-index/nicaragua?city=Managua#fixed
# Successfully fetched the webpage for -> Istanbul https://www.speedtest.net/global-index/turkey?city=Istanbul#fixed
# Successfully fetched the webpage for -> Athens https://www.speedtest.net/global-index/greece?city=Athens#fixed
# Successfully fetched the webpage for -> Skopje https://www.speedtest.net/global-index/north-macedonia?city=Skopje#fixed
# Successfully fetched the webpage for -> Dhaka https://www.speedtest.net/global-index/bangladesh?city=Dhaka#fixed
# Successfully fetched the webpage for -> Tegucigalpa https://www.speedtest.net/global-index/honduras?city=Tegucigalpa#fixed
# Successfully fetched the webpage for -> San Pedro Sula https://www.speedtest.net/global-index/honduras?city=San Pedro Sula#fixed
# Successfully fetched the webpage for -> Kinshasa https://www.speedtest.net/global-index/dr-congo?city=Kinshasa#fixed
# Successfully fetched the webpage for -> Phnom Penh https://www.speedtest.net/global-index/cambodia?city=Phnom Penh#fixed
# Successfully fetched the webpage for -> Pointe-Noire https://www.speedtest.net/global-index/congo?city=Pointe-Noire#fixed
# Successfully fetched the webpage for -> Ankara https://www.speedtest.net/global-index/turkey?city=Ankara#fixed
# Successfully fetched the webpage for -> Ouagadougou https://www.speedtest.net/global-index/burkina-faso?city=Ouagadougou#fixed
# Successfully fetched the webpage for -> Libreville https://www.speedtest.net/global-index/gabon?city=Libreville#fixed
# Successfully fetched the webpage for -> Port-au-Prince https://www.speedtest.net/global-index/haiti?city=Port-au-Prince#fixed
# Successfully fetched the webpage for -> Antananarivo https://www.speedtest.net/global-index/madagascar?city=Antananarivo#fixed
# Successfully fetched the webpage for -> Accra https://www.speedtest.net/global-index/ghana?city=Accra#fixed
# Successfully fetched the webpage for -> Baku https://www.speedtest.net/global-index/azerbaijan?city=Baku#fixed
# Successfully fetched the webpage for -> Chittagong https://www.speedtest.net/global-index/bangladesh?city=Chittagong#fixed
# Successfully fetched the webpage for -> South Jakarta https://www.speedtest.net/global-index/indonesia?city=South Jakarta#fixed
# Successfully fetched the webpage for -> Vientiane https://www.speedtest.net/global-index/laos?city=Vientiane#fixed
# Successfully fetched the webpage for -> Brazzaville https://www.speedtest.net/global-index/congo?city=Brazzaville#fixed
# Successfully fetched the webpage for -> Cairo https://www.speedtest.net/global-index/egypt?city=Cairo#fixed
# Successfully fetched the webpage for -> Baghdad https://www.speedtest.net/global-index/iraq?city=Baghdad#fixed
# Successfully fetched the webpage for -> Caracas https://www.speedtest.net/global-index/venezuela?city=Caracas#fixed
# Successfully fetched the webpage for -> Santa Cruz de la Sierra https://www.speedtest.net/global-index/bolivia?city=Santa Cruz de la Sierra#fixed
# Successfully fetched the webpage for -> Bekasi https://www.speedtest.net/global-index/indonesia?city=Bekasi#fixed
# Successfully fetched the webpage for -> Casablanca https://www.speedtest.net/global-index/morocco?city=Casablanca#fixed
# Successfully fetched the webpage for -> Dushanbe https://www.speedtest.net/global-index/tajikistan?city=Dushanbe#fixed
# Successfully fetched the webpage for -> Lome https://www.speedtest.net/global-index/togo?city=Lome#fixed
# Successfully fetched the webpage for -> La Paz https://www.speedtest.net/global-index/bolivia?city=La Paz#fixed
# Successfully fetched the webpage for -> Kigali https://www.speedtest.net/global-index/rwanda?city=Kigali#fixed
# Successfully fetched the webpage for -> Santiago De Los Caballeros https://www.speedtest.net/global-index/dominican-republic?city=Santiago De Los Caballeros#fixed
# Successfully fetched the webpage for -> Rabat https://www.speedtest.net/global-index/morocco?city=Rabat#fixed
# Successfully fetched the webpage for -> Dakar https://www.speedtest.net/global-index/senegal?city=Dakar#fixed
# Successfully fetched the webpage for -> Tbilisi https://www.speedtest.net/global-index/georgia?city=Tbilisi#fixed
# Successfully fetched the webpage for -> Cotonou https://www.speedtest.net/global-index/benin?city=Cotonou#fixed
# Successfully fetched the webpage for -> Mosul https://www.speedtest.net/global-index/iraq?city=Mosul#fixed
# Successfully fetched the webpage for -> Lagos https://www.speedtest.net/global-index/nigeria?city=Lagos#fixed
# Successfully fetched the webpage for -> Freetown https://www.speedtest.net/global-index/sierra-leone?city=Freetown#fixed
# Successfully fetched the webpage for -> Mandalay https://www.speedtest.net/global-index/myanmar-(burma)?city=Mandalay#fixed
# Successfully fetched the webpage for -> Lilongwe https://www.speedtest.net/global-index/malawi?city=Lilongwe#fixed
# Successfully fetched the webpage for -> Bamako https://www.speedtest.net/global-index/mali?city=Bamako#fixed
# Successfully fetched the webpage for -> Luanda https://www.speedtest.net/global-index/angola?city=Luanda#fixed
# Successfully fetched the webpage for -> Yangon https://www.speedtest.net/global-index/myanmar-(burma)?city=Yangon#fixed
# Successfully fetched the webpage for -> Dar es Salaam https://www.speedtest.net/global-index/tanzania?city=Dar es Salaam#fixed
# Successfully fetched the webpage for -> Lusaka https://www.speedtest.net/global-index/zambia?city=Lusaka#fixed
# Successfully fetched the webpage for -> Nouakchott https://www.speedtest.net/global-index/mauritania?city=Nouakchott#fixed
# Successfully fetched the webpage for -> Colombo https://www.speedtest.net/global-index/sri-lanka?city=Colombo#fixed
# Successfully fetched the webpage for -> Karachi https://www.speedtest.net/global-index/pakistan?city=Karachi#fixed
# Successfully fetched the webpage for -> Algiers https://www.speedtest.net/global-index/algeria?city=Algiers#fixed
# Successfully fetched the webpage for -> Mogadishu https://www.speedtest.net/global-index/somalia?city=Mogadishu#fixed
# Successfully fetched the webpage for -> Djibouti https://www.speedtest.net/global-index/djibouti?city=Djibouti#fixed
# Successfully fetched the webpage for -> Maputo https://www.speedtest.net/global-index/mozambique?city=Maputo#fixed
# Successfully fetched the webpage for -> Lahore https://www.speedtest.net/global-index/pakistan?city=Lahore#fixed
# Successfully fetched the webpage for -> Tehran https://www.speedtest.net/global-index/iran?city=Tehran#fixed
# Successfully fetched the webpage for -> Tripoli https://www.speedtest.net/global-index/libya?city=Tripoli#fixed
# Successfully fetched the webpage for -> Kampala https://www.speedtest.net/global-index/uganda?city=Kampala#fixed
# Successfully fetched the webpage for -> Harare https://www.speedtest.net/global-index/zimbabwe?city=Harare#fixed
# Successfully fetched the webpage for -> Mashhad https://www.speedtest.net/global-index/iran?city=Mashhad#fixed
# Successfully fetched the webpage for -> Nairobi https://www.speedtest.net/global-index/kenya?city=Nairobi#fixed
# Successfully fetched the webpage for -> Oran https://www.speedtest.net/global-index/algeria?city=Oran#fixed
# Successfully fetched the webpage for -> Mombasa https://www.speedtest.net/global-index/kenya?city=Mombasa#fixed
# Successfully fetched the webpage for -> Yaounde https://www.speedtest.net/global-index/cameroon?city=Yaounde#fixed
# Successfully fetched the webpage for -> Douala https://www.speedtest.net/global-index/cameroon?city=Douala#fixed
# Successfully fetched the webpage for -> Niamey https://www.speedtest.net/global-index/niger?city=Niamey#fixed
# Successfully fetched the webpage for -> Hargeisa https://www.speedtest.net/global-index/somalia?city=Hargeisa#fixed
# Successfully fetched the webpage for -> Beirut https://www.speedtest.net/global-index/lebanon?city=Beirut#fixed
# Successfully fetched the webpage for -> Conakry https://www.speedtest.net/global-index/guinea?city=Conakry#fixed
# Successfully fetched the webpage for -> Tunis https://www.speedtest.net/global-index/tunisia?city=Tunis#fixed
# Successfully fetched the webpage for -> Monrovia https://www.speedtest.net/global-index/liberia?city=Monrovia#fixed
# Successfully fetched the webpage for -> Sfax https://www.speedtest.net/global-index/tunisia?city=Sfax#fixed
# Successfully fetched the webpage for -> Addis Ababa https://www.speedtest.net/global-index/ethiopia?city=Addis Ababa#fixed
# Successfully fetched the webpage for -> Ashgabat https://www.speedtest.net/global-index/turkmenistan?city=Ashgabat#fixed
# Successfully fetched the webpage for -> Sana'a https://www.speedtest.net/global-index/yemen?city=Sana'a#fixed
# Successfully fetched the webpage for -> Aden https://www.speedtest.net/global-index/yemen?city=Aden#fixed
# Successfully fetched the webpage for -> Kabul https://www.speedtest.net/global-index/afghanistan?city=Kabul#fixed
# Successfully fetched the webpage for -> Herat https://www.speedtest.net/global-index/afghanistan?city=Herat#fixed
# Successfully fetched the webpage for -> Havana https://www.speedtest.net/global-index/cuba?city=Havana#fixed

# %%
import pandas as pd

# %%
countries_mobile_df = pd.DataFrame(countries_mobile_data)

csv_filename = 'countries_mobile_data.csv'

countries_mobile_df.to_csv(csv_filename, index=False)

print(f"Data has been written to '{csv_filename}' successfully.")

countries_mobile_df.head()
# Out:
# Data has been written to 'countries_mobile_data.csv' successfully.
#                 country position rank_change download upload latency
# 0                 Qatar        1           -   313.30  27.53      19
# 1  United Arab Emirates        2           -   296.00  26.25      19
# 2                Kuwait        3           -   228.64  23.73      18
# 3               Iceland        4          +4   158.32  20.22      17
# 4           South Korea        5          -1   156.23  17.68      30

# %%
cities_mobile_df = pd.DataFrame(cities_mobile_data)

csv_filename = 'cities_mobile_data.csv'

cities_mobile_df.to_csv(csv_filename, index=False)

print(f"Data has been written to '{csv_filename}' successfully.")

cities_mobile_df.head()
# Out:
# Data has been written to 'cities_mobile_data.csv' successfully.
#         city position rank_change download upload latency
# 0  Ar-Rayyan        1           -   427.38  27.58      19
# 1      Dubai        2           -   358.00  30.81      18
# 2  Abu Dhabi        3           -   303.71  24.10      22
# 3       Doha        4          +1   287.57  28.42      19
# 4     Riyadh        5          +2   269.95  21.41      19

# %%
countries_broadband_df = pd.DataFrame(countries_broadband_data)

csv_filename = 'countries_broadband_data.csv'

countries_broadband_df.to_csv(csv_filename, index=False)

print(f"Data has been written to '{csv_filename}' successfully.")

countries_broadband_df.head()
# Out:
# Data has been written to 'countries_broadband_data.csv' successfully.
#                 country position rank_change download  upload latency
# 0             Singapore        1           -   284.13  229.80       4
# 1  United Arab Emirates        2          +3   276.02  134.85       5
# 2       Hong Kong (SAR)        3           -   274.26  193.14       4
# 3                 Chile        4          -2   265.12  168.13       6
# 4         United States        5          +1   254.01   31.37      13

# %%
cities_broadband_df = pd.DataFrame(cities_broadband_data)

csv_filename = 'cities_broadband_data.csv'

cities_broadband_df.to_csv(csv_filename, index=False)

print(f"Data has been written to '{csv_filename}' successfully.")

cities_broadband_df.head()
# Out:
# Data has been written to 'cities_broadband_data.csv' successfully.
#          city position rank_change download  upload latency
# 0   Abu Dhabi        1           -   308.05  176.57       5
# 1     Beijing        2           -   291.70   39.32      12
# 2  Valparaíso        3           -   291.28  188.15       5
# 3        Lyon        4          +1   285.67  210.25       6
# 4    Shanghai        5          -1   285.39   59.40       6

# %%
# SQL CREATE TABLE statements for each DataFrame
sql_statements = []
table_data = [('countries_mobile_data', countries_mobile_df), ('cities_mobile_data', cities_mobile_df), ('countries_broadband_data', countries_broadband_df), ('cities_broadband_data', cities_broadband_df)]

database_name = 'web_scrapping'
create_db_statement = f'CREATE DATABASE IF NOT EXISTS `{database_name}`;'
use_db = f'USE `{database_name}`;'
sql_statements.append(create_db_statement)
sql_statements.append(use_db)

for df_name, df in table_data:
    columns = ', '.join([f'{col} VARCHAR(255)' for col in df.columns])
    sql_statement = f'CREATE TABLE {df_name} ({columns});'
    sql_statements.append(sql_statement)

# SQL INSERT INTO statements for each DataFrame
for df_name, df in table_data:
    insert_sql = f'INSERT INTO {df_name} ({", ".join(df.columns)}) VALUES '
    values = ', '.join([str(tuple(row)) for row in df.values])
    sql_statements.append(insert_sql + values + ';')

# SQL statements to a .sql file
sql_filename = 'database_setup.sql'
with open(sql_filename, 'w') as file:
    for sql_statement in sql_statements:
        file.write(sql_statement + '\n')

print(f"SQL statements have been written to '{sql_filename}' successfully.")
# Out:
# SQL statements have been written to 'database_setup.sql' successfully.
